# %%
import numpy as np 
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = ['P. Lee', 'R. Jones', 'J. Smith', 'A. Patel', 'M. Owen', 'S. Green', 'N. Cook', 'W. Hands', 'P. Rice', 'F. Marsh']
age = [35, 52, 45, 70, 24, 43, 68, 77, 45, 28]
gender  = ['Female', 'Male','Male','Female', 'Male', 'Male', 'Male','Female', 'Female', 'Male' ]
blood_group = ['A Rh+', 'O Rh-', 'O Rh+','O Rh-','A Rh-','O Rh-','A Rh+','O Rh-','O Rh+','O Rh+',]
weight = [50, 115, 96, 41, 79, 109, 73, 104, 64, 136]
height = [1.52, 1.77, 1.83, 1.55, 1.82, 1.89, 1.76, 1.71, 1.74, 1.78]
systolic_blood_pressure = [68, 110, 88, 76, 65, 114, 108, 107, 101, 121]
diastolic_blood_pressure = [112, 154, 136, 125, 105, 159, 136, 145, 132, 165]
temperature = [98.7, 98.5, 98.8, 98.6, 98.7, 98.9, 99, 98.3, 98.6, 98.7]
diabetes = [0,1,0,0,0,1,0,1,0,1]

# %%
df = pd.DataFrame({'name':name, 'age':age, 'gender':gender, 'blood_group':blood_group, 'weight':weight, 'height':height, 'systolic_blood_pressure':systolic_blood_pressure, 'diastolic_blood_pressure':diastolic_blood_pressure, 'temperature':temperature, 'diabetes':diabetes})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 df = pd.DataFrame[{'name':name, 'age':age, 'gender':gender, 'blood_group':blood_group, 'weight':weight, 'height':height, 'systolic_blood_pressure':systolic_blood_pressure, 'diastolic_blood_pressure':diastolic_blood_pressure, 'temperature':temperature, 'diabetes':diabetes}]
#
# TypeError: type 'DataFrame' is not subscriptable
