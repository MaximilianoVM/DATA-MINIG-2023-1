# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximilianoVM/DATA-MINIG-2023-1/blob/main/project/0_GC_EXPLORING_AGEBS_ENSENADA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plts

# %matplotlib inline

# %% [markdown]
# traemos los datos de github

# %%
url10 = 'https://raw.githubusercontent.com/MaximilianoVM/DATA-MINIG-2023-1/main/project/DATA/RESAGEB2010%20-%2002%20Baja%20California.txt'
url20 = 'https://raw.githubusercontent.com/MaximilianoVM/DATA-MINIG-2023-1/main/project/DATA/RESAGEBURB2020%20-%2002%20Baja%20California.csv'

data10=pd.read_csv(url10)
data20=pd.read_csv(url20)
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# #=========2010=========

# %%
data10
# Out:
#        ENTIDAD          NOM_ENT  MUN                              NOM_MUN  \
# 0            2  Baja California    0  Total de la entidad Baja California
# 1            2  Baja California    1                             Ensenada
# 2            2  Baja California    1                             Ensenada
# 3            2  Baja California    1                             Ensenada
# 4            2  Baja California    1                             Ensenada
# ...        ...              ...  ...                                  ...
# 29995        2  Baja California    4                              Tijuana
# 29996        2  Baja California    4                              Tijuana
# 29997        2  Baja California    4                              Tijuana
# 29998        2  Baja California    4                              Tijuana
# 29999        2  Baja California    4                              Tijuana
#
#        LOC                       NOM_LOC  AGEB  MZA  P_TOTAL   P_0A2   P_3A5  \
# ...

# %%
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ENTIDAD     30000 non-null  int64
#  1   NOM_ENT     30000 non-null  object
#  2   MUN         30000 non-null  int64
#  3   NOM_MUN     30000 non-null  object
#  4   LOC         30000 non-null  int64
#  5   NOM_LOC     30000 non-null  object
#  6   AGEB        30000 non-null  object
#  7   MZA         30000 non-null  int64
#  8   P_TOTAL     30000 non-null  int64
#  9   P_0A2       30000 non-null  object
#  10  P_3A5       30000 non-null  object
#  11  POB65_MAS   30000 non-null  object
#  12  GRAPROES    30000 non-null  object
#  13  PROM_HNV    30000 non-null  object
#  14  VIVTOT      30000 non-null  int64
#  15  PRO_OCUP_C  30000 non-null  object
#  16  PROM_OCUP   30000 non-null  object
#  17  VPH_PC      30000 non-null  object
#  18  PNACOE      30000 non-null  object
# ...

# %% [markdown]
# ##limpiando 2010

# %%
#filtramos para solo ensenada
clean10 = data10[ data10['NOM_MUN'] == 'Ensenada' ]
#Baja California es redundante
clean10 = clean10.drop(columns=['ENTIDAD','NOM_ENT','MUN'])

clean10
# Out:
#        NOM_MUN   LOC                               NOM_LOC  AGEB  MZA  \
# 1     Ensenada     0                   TOTAL DEL MUNICIPIO  0000    0
# 2     Ensenada     1          Total de la localidad urbana  0000    0
# 3     Ensenada     1                     Total AGEB urbana  0435    0
# 4     Ensenada     1                              Ensenada  0435    1
# 5     Ensenada     1                              Ensenada  0435    3
# ...        ...   ...                                   ...   ...  ...
# 8998  Ensenada  3370  Colonia Lomas de San Ramón (Triquis)  8816   28
# 8999  Ensenada  3370  Colonia Lomas de San Ramón (Triquis)  8816   29
# 9000  Ensenada  3370  Colonia Lomas de San Ramón (Triquis)  8816   30
# 9001  Ensenada  3370                     Total AGEB urbana  9528    0
# 9002  Ensenada  3370  Colonia Lomas de San Ramón (Triquis)  9528    1
#
#       P_TOTAL  P_0A2  P_3A5 POB65_MAS GRAPROES PROM_HNV  VIVTOT PRO_OCUP_C  \
# ...

# %% [markdown]
# ### Que localidades hay en ensenada? (2010)

# %%
print( clean10['NOM_LOC'].unique() )

print( '\n' ,len(clean10['NOM_LOC'].unique()) ) 

localidades10 = [clean10['NOM_LOC'].unique()[i] for i in range(3, len(clean10['NOM_LOC'].unique()))]

print(localidades10)
# Out:
# ['TOTAL DEL MUNICIPIO' 'Total de la localidad urbana' 'Total AGEB urbana'
#  'Ensenada' 'Camalú' 'Francisco Zarco (Valle de Guadalupe)'
#  'Lázaro Cárdenas' 'Rodolfo Sánchez Taboada (Maneadero)'
#  'Ejido México (Punta Colonet)' 'Real del Castillo Nuevo (Ojos Negros)'
#  'San Vicente' 'El Sauzal de Rodríguez' 'Vicente Guerrero' 'Santa Fe'
#  'San Quintín' 'Lázaro Cárdenas (Valle de la Trinidad)' 'Emiliano Zapata'
#  'Ejido Papalote' 'Rancho Verde' 'Benito García (El Zorrillo)'
#  'Colonia Nueva Era' 'Colonia Lomas de San Ramón (Triquis)']
#
#  22
# ...

# %%
loc_series10 = pd.Series(localidades10)
loc_series10
# Out:
# 0                                   Ensenada
# 1                                     Camalú
# 2       Francisco Zarco (Valle de Guadalupe)
# 3                            Lázaro Cárdenas
# 4        Rodolfo Sánchez Taboada (Maneadero)
# 5               Ejido México (Punta Colonet)
# 6      Real del Castillo Nuevo (Ojos Negros)
# 7                                San Vicente
# 8                     El Sauzal de Rodríguez
# 9                           Vicente Guerrero
# 10                                  Santa Fe
# 11                               San Quintín
# 12    Lázaro Cárdenas (Valle de la Trinidad)
# 13                           Emiliano Zapata
# 14                            Ejido Papalote
# 15                              Rancho Verde
# 16               Benito García (El Zorrillo)
# 17                         Colonia Nueva Era
# 18      Colonia Lomas de San Ramón (Triquis)
# dtype: object

# %% [markdown]
# #=========2020=========

# %%
data20
# Out:
#        ENTIDAD          NOM_ENT  MUN                              NOM_MUN  \
# 0            2  Baja California    0  Total de la entidad Baja California
# 1            2  Baja California    1                             Ensenada
# 2            2  Baja California    1                             Ensenada
# 3            2  Baja California    1                             Ensenada
# 4            2  Baja California    1                             Ensenada
# ...        ...              ...  ...                                  ...
# 29995        2  Baja California    4                              Tijuana
# 29996        2  Baja California    4                              Tijuana
# 29997        2  Baja California    4                              Tijuana
# 29998        2  Baja California    4                              Tijuana
# 29999        2  Baja California    4                              Tijuana
#
#        LOC                       NOM_LOC  AGEB  MZA   POBTOT   P_0A2   P_3A5  \
# ...

# %%
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ENTIDAD     30000 non-null  int64
#  1   NOM_ENT     30000 non-null  object
#  2   MUN         30000 non-null  int64
#  3   NOM_MUN     30000 non-null  object
#  4   LOC         30000 non-null  int64
#  5   NOM_LOC     30000 non-null  object
#  6   AGEB        30000 non-null  object
#  7   MZA         30000 non-null  int64
#  8   POBTOT      30000 non-null  int64
#  9   P_0A2       30000 non-null  object
#  10  P_3A5       30000 non-null  object
#  11  POB65_MAS   30000 non-null  object
#  12  GRAPROES    30000 non-null  object
#  13  PROM_HNV    30000 non-null  object
#  14  PNACOE      30000 non-null  object
#  15  VIVTOT      30000 non-null  int64
#  16  PROM_OCUP   30000 non-null  object
#  17  PRO_OCUP_C  30000 non-null  object
#  18  VPH_PC      30000 non-null  object
# ...

# %% [markdown]
# ##limpiando 2020

# %%
#filtramos para solo ensenada
clean20 = data20[ data20['NOM_MUN'] == 'Ensenada' ]
#Baja California es redundante
clean20 = clean20.drop(columns=['ENTIDAD','NOM_ENT','MUN'])

clean20
# Out:
#        NOM_MUN   LOC                                 NOM_LOC  AGEB  MZA  \
# 1     Ensenada     0                     Total del municipio  0000    0
# 2     Ensenada     1            Total de la localidad urbana  0000    0
# 3     Ensenada     1                       Total AGEB urbana  0026    0
# 4     Ensenada     1                                Ensenada  0026    1
# 5     Ensenada     1                                Ensenada  0026    2
# ...        ...   ...                                     ...   ...  ...
# 8323  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782   32
# 8324  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782   33
# 8325  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782   34
# 8326  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782   35
# 8327  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782   36
#
#       POBTOT  P_0A2  P_3A5 POB65_MAS GRAPROES PROM_HNV  PNACOE  VIVTOT  \
# ...

# %% [markdown]
# ###Que localidades hay en ensenada? (2020)

# %%
print( clean20['NOM_LOC'].unique() )

print( '\n' ,len(clean20['NOM_LOC'].unique()) ) 

localidades20 = [clean20['NOM_LOC'].unique()[i] for i in range(3, len(clean20['NOM_LOC'].unique()))]

print(localidades20)
# Out:
# ['Total del municipio' 'Total de la localidad urbana' 'Total AGEB urbana'
#  'Ensenada' 'Francisco Zarco (Valle de Guadalupe)'
#  'Rodolfo Sánchez Taboada (Maneadero)'
#  'Ejido Punta Colnett (Punta Colonet)'
#  'Real del Castillo Nuevo (Ojos Negros)' 'San Vicente'
#  'El Sauzal de Rodríguez' 'Lázaro Cárdenas (Valle de la Trinidad)'
#  'Rancho Cañón Buena Vista (El Zorrillo)']
#
#  12
# ['Ensenada', 'Francisco Zarco (Valle de Guadalupe)', 'Rodolfo Sánchez Taboada (Maneadero)', 'Ejido Punta Colnett (Punta Colonet)', 'Real del Castillo Nuevo (Ojos Negros)', 'San Vicente', 'El Sauzal de Rodríguez', 'Lázaro Cárdenas (Valle de la Trinidad)', 'Rancho Cañón Buena Vista (El Zorrillo)']

# %%
loc_series20 = pd.Series(localidades20)
loc_series20
# Out:
# 0                                  Ensenada
# 1      Francisco Zarco (Valle de Guadalupe)
# 2       Rodolfo Sánchez Taboada (Maneadero)
# 3       Ejido Punta Colnett (Punta Colonet)
# 4     Real del Castillo Nuevo (Ojos Negros)
# 5                               San Vicente
# 6                    El Sauzal de Rodríguez
# 7    Lázaro Cárdenas (Valle de la Trinidad)
# 8    Rancho Cañón Buena Vista (El Zorrillo)
# dtype: object

# %%
print( clean20['LOC'].unique() )

print( '\n' ,len( clean20['LOC'].unique() ) )
# Out:
# [   0    1  114  139  186  190  243  247  935 2183]
#
#  10

# %% [markdown]
# #===COMPARANDO 2010 CON 2020

# %%
loc_series10
# Out:
# 0                                   Ensenada
# 1                                     Camalú
# 2       Francisco Zarco (Valle de Guadalupe)
# 3                            Lázaro Cárdenas
# 4        Rodolfo Sánchez Taboada (Maneadero)
# 5               Ejido México (Punta Colonet)
# 6      Real del Castillo Nuevo (Ojos Negros)
# 7                                San Vicente
# 8                     El Sauzal de Rodríguez
# 9                           Vicente Guerrero
# 10                                  Santa Fe
# 11                               San Quintín
# 12    Lázaro Cárdenas (Valle de la Trinidad)
# 13                           Emiliano Zapata
# 14                            Ejido Papalote
# 15                              Rancho Verde
# 16               Benito García (El Zorrillo)
# 17                         Colonia Nueva Era
# 18      Colonia Lomas de San Ramón (Triquis)
# dtype: object

# %%
loc_series20
# Out:
# 0                                  Ensenada
# 1      Francisco Zarco (Valle de Guadalupe)
# 2       Rodolfo Sánchez Taboada (Maneadero)
# 3       Ejido Punta Colnett (Punta Colonet)
# 4     Real del Castillo Nuevo (Ojos Negros)
# 5                               San Vicente
# 6                    El Sauzal de Rodríguez
# 7    Lázaro Cárdenas (Valle de la Trinidad)
# 8    Rancho Cañón Buena Vista (El Zorrillo)
# dtype: object

# %% [markdown]
# hacemos una lista a partir de los elementos que comparten

# %%
localidades = [x for x in localidades10 if x in localidades20]

# %%
localidades
# Out:
# ['Ensenada',
#  'Francisco Zarco (Valle de Guadalupe)',
#  'Rodolfo Sánchez Taboada (Maneadero)',
#  'Real del Castillo Nuevo (Ojos Negros)',
#  'San Vicente',
#  'El Sauzal de Rodríguez',
#  'Lázaro Cárdenas (Valle de la Trinidad)']

# %% [markdown]
# [ ! ] [ ! ][ ! ]  punta colonet y el zorrillo cambiaron de nombre entre 2010 y 2020

# %% [markdown]
# vamos a hacer coincidir los nombres

# %%
# Replace values in the 'NOM_LOC' column based on conditions
clean10.loc[clean10['NOM_LOC'] == 'Ejido México (Punta Colonet)', 'NOM_LOC'] = 'Ejido Punta Colnett (Punta Colonet)'
clean10.loc[clean10['NOM_LOC'] == 'Benito García (El Zorrillo)', 'NOM_LOC'] = 'Rancho Cañón Buena Vista (El Zorrillo)'

# %% [markdown]
# ahora volvemos a sacar las localidades 2010

# %%
#print( clean10['NOM_LOC'].unique() )

#print( '\n' ,len(clean10['NOM_LOC'].unique()) ) 

localidades10 = [clean10['NOM_LOC'].unique()[i] for i in range(3, len(clean10['NOM_LOC'].unique()))]

#print(localidades10)

loc_series10 = pd.Series(localidades10)
loc_series10
# Out:
# 0                                   Ensenada
# 1                                     Camalú
# 2       Francisco Zarco (Valle de Guadalupe)
# 3                            Lázaro Cárdenas
# 4        Rodolfo Sánchez Taboada (Maneadero)
# 5        Ejido Punta Colnett (Punta Colonet)
# 6      Real del Castillo Nuevo (Ojos Negros)
# 7                                San Vicente
# 8                     El Sauzal de Rodríguez
# 9                           Vicente Guerrero
# 10                                  Santa Fe
# 11                               San Quintín
# 12    Lázaro Cárdenas (Valle de la Trinidad)
# 13                           Emiliano Zapata
# 14                            Ejido Papalote
# 15                              Rancho Verde
# 16    Rancho Cañón Buena Vista (El Zorrillo)
# 17                         Colonia Nueva Era
# 18      Colonia Lomas de San Ramón (Triquis)
# dtype: object

# %% [markdown]
# de nuevo hacemos la lista con los elementos que comparten

# %%
localidades = [x for x in localidades10 if x in localidades20]

localidades
# Out:
# ['Ensenada',
#  'Francisco Zarco (Valle de Guadalupe)',
#  'Rodolfo Sánchez Taboada (Maneadero)',
#  'Ejido Punta Colnett (Punta Colonet)',
#  'Real del Castillo Nuevo (Ojos Negros)',
#  'San Vicente',
#  'El Sauzal de Rodríguez',
#  'Lázaro Cárdenas (Valle de la Trinidad)',
#  'Rancho Cañón Buena Vista (El Zorrillo)']

# %% [markdown]
# ahora si, con estas localidades vamos a trabajar

# %% [markdown]
# ahora vamos a eliminar todas las localidades que no sean estas de ambos dataframes (2010 y 2020)

# %% [markdown]
# ## limpiando localidades

# %%
localidades
# Out:
# ['Ensenada',
#  'Francisco Zarco (Valle de Guadalupe)',
#  'Rodolfo Sánchez Taboada (Maneadero)',
#  'Ejido Punta Colnett (Punta Colonet)',
#  'Real del Castillo Nuevo (Ojos Negros)',
#  'San Vicente',
#  'El Sauzal de Rodríguez',
#  'Lázaro Cárdenas (Valle de la Trinidad)',
#  'Rancho Cañón Buena Vista (El Zorrillo)']

# %% [markdown]
# nos quedamos solo con esas localidades

# %%
# create a boolean mask to filter rows
mask10 = clean10['NOM_LOC'].isin(localidades)

# apply the mask to select only the rows with allowed values
clean10 = clean10[mask10]

clean10 = clean10.reset_index()

#========================

# create a boolean mask to filter rows
mask20 = clean20['NOM_LOC'].isin(localidades)

# apply the mask to select only the rows with allowed values
clean20 = clean20[mask20]

clean20 = clean20.reset_index()

# %%
clean10['NOM_LOC'].unique()
# Out:
# array(['Ensenada', 'Francisco Zarco (Valle de Guadalupe)',
#        'Rodolfo Sánchez Taboada (Maneadero)',
#        'Ejido Punta Colnett (Punta Colonet)',
#        'Real del Castillo Nuevo (Ojos Negros)', 'San Vicente',
#        'El Sauzal de Rodríguez', 'Lázaro Cárdenas (Valle de la Trinidad)',
#        'Rancho Cañón Buena Vista (El Zorrillo)'], dtype=object)

# %%
clean20['NOM_LOC'].unique()
# Out:
# array(['Ensenada', 'Francisco Zarco (Valle de Guadalupe)',
#        'Rodolfo Sánchez Taboada (Maneadero)',
#        'Ejido Punta Colnett (Punta Colonet)',
#        'Real del Castillo Nuevo (Ojos Negros)', 'San Vicente',
#        'El Sauzal de Rodríguez', 'Lázaro Cárdenas (Valle de la Trinidad)',
#        'Rancho Cañón Buena Vista (El Zorrillo)'], dtype=object)

# %%
clean10
# Out:
#       index   NOM_MUN   LOC                                 NOM_LOC  AGEB  \
# 0         4  Ensenada     1                                Ensenada  0435
# 1         5  Ensenada     1                                Ensenada  0435
# 2         6  Ensenada     1                                Ensenada  0435
# 3         7  Ensenada     1                                Ensenada  0435
# 4         8  Ensenada     1                                Ensenada  0435
# ...     ...       ...   ...                                     ...   ...
# 7026   8846  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 7027   8847  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 7028   8848  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 7029   8849  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 7030   8850  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
#
#       MZA  P_TOTAL P_0A2 P_3A5 POB65_MAS GRAPROES PROM_HNV  VIVTOT PRO_OCUP_C  \
# ...

# %%
clean20
# Out:
#       index   NOM_MUN   LOC                                 NOM_LOC  AGEB  \
# 0         4  Ensenada     1                                Ensenada  0026
# 1         5  Ensenada     1                                Ensenada  0026
# 2         6  Ensenada     1                                Ensenada  0026
# 3         8  Ensenada     1                                Ensenada  0030
# 4         9  Ensenada     1                                Ensenada  0030
# ...     ...       ...   ...                                     ...   ...
# 8005   8323  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 8006   8324  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 8007   8325  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 8008   8326  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
# 8009   8327  Ensenada  2183  Rancho Cañón Buena Vista (El Zorrillo)  9782
#
#       MZA  POBTOT P_0A2 P_3A5 POB65_MAS GRAPROES PROM_HNV PNACOE  VIVTOT  \
# ...

# %% [markdown]
# san vicente por curiosidad

# %%
clean10 [ clean10['NOM_LOC'] == 'San Vicente' ]
# Out:
#       index   NOM_MUN  LOC      NOM_LOC  AGEB  MZA  P_TOTAL P_0A2 P_3A5  \
# 6374   7236  Ensenada  243  San Vicente  1819    1        9     *     *
# 6375   7238  Ensenada  243  San Vicente  8178    1       25     *     *
# 6376   7239  Ensenada  243  San Vicente  8178    2       47     5     3
# 6377   7240  Ensenada  243  San Vicente  8178    3       16     *     0
# 6378   7241  Ensenada  243  San Vicente  8178    4       12     0     *
# ...     ...       ...  ...          ...   ...  ...      ...   ...   ...
# 6525   7391  Ensenada  243  San Vicente  820A   38       44     *     5
# 6526   7392  Ensenada  243  San Vicente  820A   39       43     *     3
# 6527   7393  Ensenada  243  San Vicente  820A   41        4     *     *
# 6528   7394  Ensenada  243  San Vicente  820A   44        0     0     0
# 6529   7395  Ensenada  243  San Vicente  820A   45        9     *     *
#
#      POB65_MAS GRAPROES PROM_HNV  VIVTOT PRO_OCUP_C PROM_OCUP VPH_PC PNACOE
# ...

# %% [markdown]
# ## renombrando variables

# %% [markdown]
# no quiero la columna index 2, ni se de donde salio

# %%
#clean10.drop('index', axis=1, inplace=True)
#clean20.drop('index', axis=1, inplace=True)

# %% [markdown]
# ### 2010 como base

# %% [markdown]
# que columnas tenemos en los datos de 2010?

# %%
pd.Series(clean10.columns)
# Out:
# 0          index
# 1        NOM_MUN
# 2            LOC
# 3        NOM_LOC
# 4           AGEB
# 5            MZA
# 6        P_TOTAL
# 7          P_0A2
# 8          P_3A5
# 9      POB65_MAS
# 10      GRAPROES
# 11      PROM_HNV
# 12        VIVTOT
# 13    PRO_OCUP_C
# 14     PROM_OCUP
# 15        VPH_PC
# 16        PNACOE
# dtype: object

# %% [markdown]
# que significan?

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|c|}
# \hline \begin{array}{l}
# \text { Categoria o indicador } \\
# 2010
# \end{array} & \text { Descripción } & \text { Mnemónico } & \text { Rangos } & \text { Long } \\
# \hline \text { Clave de localidad } & \begin{array}{l}
# \text { Clave que identifica a la localidad, al interior de } \\
# \text { cada municipio (o delegaciôn politica) conforme } \\
# \text { al Marco Geoestadistico Nacional. }
# \end{array} & \text { LOC } & 0000, \ldots, 9999 & 4 \\
# \hline \text { Localidad } & \begin{array}{l}
# \text { Nombre con el que se reconoce a la localidad } \\
# \text { dado por la ley o la costumbre. }
# \end{array} & \text { NOM_LOC } & \text { Alfanumérico } & 70 \\
# \hline \text { Clave de AGEB } & \begin{array}{l}
# \text { Clave que identifica al AGEB urbana, al interior } \\
# \text { de una localidad, de acuerdo a la } \\
# \text { desagregación del Marco Geoestadistico } \\
# \text { Nacional. }
# \end{array} & \text { AGEB } & \underset{\mathrm{A}}{001, \ldots, \ldots 99,0,9} & 4 \\
# \hline \text { Clave de manzana } & \begin{array}{l}
# \text { Clave que identifica a la manzana, al interior de } \\
# \text { una AGEB, de acuerdo a la desagregación del } \\
# \text { Marco Geoestadistico Nacional }
# \end{array} & \text { MZA } & 001, \ldots, 999 & 3 \\
# \hline \text { Población total } & \begin{array}{l}
# \text { Total de personas que residen habitualmente } \\
# \text { en el pais, entidad federativa, municipio y } \\
# \text { localidad. Incluye la estimación del número de } \\
# \text { personas en viviendas particulares sin } \\
# \text { información de ocupantes. Incluye a la } \\
# \text { población que no especificósu su edad. }
# \end{array} & \text { РОВТОТ } & 0, \ldots, 999999999 & 9 \\
# \hline \text { Población de } 0 \text { a } 2 \text { años } & \text { Personas de } 0 \text { a } 2 \text { años de edad. } & \text { P_0A2 } & 0, \ldots, 999999999 & 9 \\
# \hline \text { Población de } 3 \text { a } 5 \text { años } & \text { Personas de } 3 \text { a } 5 \text { años de edad. } & P_{-} 3 A5 & 0, \ldots, 999999999 & 9 \\
# \hline \text { Población de } 65 \text { años y más } & \text { Personas de } 65 \text { a } 130 \text { años de edad. } & \text { POB65_MAS } & 0, \ldots, 999999999 & 9 \\
# \hline \text { Grado promedio de escolaridad } & \begin{array}{l}
# \text { Resultado de dividir el monto de grados } \\
# \text { escolares aprobados por las personas de } 15 \text { a } \\
# 130 \text { años de edad entre las personas del } \\
# \text { mismo grupo de edad. Excluye a las personas } \\
# \text { que no especificaron los grados aprobados. }
# \end{array} & \text { GRAPROES } & 0, \ldots, 999999999 & 9 \\
# \hline \text { Promedio de hijos nacidos vivos } & \begin{array}{l}
# \text { Resultado de dividir el total de hijos nacidos } \\
# \text { vivos de las mujeres do } 12 \text { a } 130 \text { años do edad, } \\
# \text { entre el total de mujeres del mismo grupo de } \\
# \text { edad. Excluye a las mujeres que no } \\
# \text { especificaron el número de hijos. }
# \end{array} & \text { PROM_HNV } & 0, \ldots, 999999999 & 9 \\
# \hline \text { Total de viviendas } & \begin{array}{l}
# \text { Viviendas particulares habitadas, deshabitadas, } \\
# \text { de uso temporal y colectivas. } \\
# \text { Incluye a las viviendas particulares sin } \\
# \text { información de sus ocupantes. }
# \end{array} & \text { VIVTOT } & 0, \ldots 99999999 & 8 \\
# \hline \begin{array}{l}
# \text { Promedio de ocupantes por } \\
# \text { cuarto en viviendas particulares } \\
# \text { habitadas }
# \end{array} & \begin{array}{l}
# \text { Resultado de dividir el número de personas que } \\
# \text { residen en viviendas particulares habitadas } \\
# \text { entre el número de cuartos de esas viviendas. } \\
# \text { Comprende las viviendas particulares para las } \\
# \text { que se captaron las caracteristicas de la } \\
# \text { vivienda, clasificadas como casa } \\
# \text { independiente, departamento en edificio, } \\
# \text { vivienda o cuarto en vecindad y vivienda o } \\
# \text { cuarto en azotea y a las que no especificaron } \\
# \text { clase de vivienda. }
# \end{array} & \text { PRO_OCUP_C } & 0, \ldots 99999999 & 8 \\
# \hline \begin{array}{l}
# \text { Promedio de ocupantes en } \\
# \text { viviendas particulares habitadas }
# \end{array} & \begin{array}{l}
# \text { Resultado de dividir el número de personas que } \\
# \text { residen en viviendas particulares habitadas, } \\
# \text { entre el número de esas viviendas. Excluye la } \\
# \text { estimación del número de personas y de } \\
# \text { viviendas particulares sin información de } \\
# \text { ocupantes. }
# \end{array} & \text { PROM_OCUP } & 0, \ldots 99999999 & 8 \\
# \hline \begin{array}{l}
# \text { Viviendas particulares } \\
# \text { habitadas que disponen de } \\
# \text { computadora }
# \end{array} & \begin{array}{l}
# \text { Viviendas particulares habitadas que tienen } \\
# \text { computadora. Comprende las viviendas } \\
# \text { particulares para las que se captaron las } \\
# \text { caracteristicas de la vivienda, clasificadas } \\
# \text { como casa independiente, departamento en } \\
# \text { edificio, vivienda o cuarto en vecindad y } \\
# \text { vivienda o cuarto en azotea y a las que no } \\
# \text { especificaron clase de vivienda. }
# \end{array} & \text { VPH_PC } & 0, \ldots 99999999 & 8 \\
# \hline \begin{array}{l}
# \text { Población nacida en otra } \\
# \text { entidad }
# \end{array} & \text { Personas nacidas en otria entidad federativa. } & \text { PNACOE } & 0, \ldots, 999999999 & 9 \\
# \hline
# \end{array}
# $$

# %%
dic10 = {
    "LOC": "Clave de localidad",
    "NOM_LOC": "Localidad",
    "AGEB": "Clave de AGEB",
    "MZA": "Clave de manzana",
    "POBTOT": "Poblacion total",
    "P_0A2": "Poblacion de 0 a 2 años",
    "P_3A5": "Poblacion de 3 a 5 años",
    "POB65_MAS": "Poblacion de 65 años y mas",
    "GRAPROES": "Grado promedio de escolaridad",
    "PROM_HNV": "Promedio de hijos nacidos vivos",
    "VIVTOT": "Total de viviendas",
    "PRO_OCUP_C":	"Promedio de ocupantes por cuarto",
    "PROM_OCUP":	"Promedio de ocupantes por vivienda",
    "VPH_PC":	"Viviendas que disponen de computadora",
    "PNACOE":	"Poblacion nacida en otra entidad"
}

# %% [markdown]
# ### adaptamos 2020

# %% [markdown]
# que columnas tenemos en los datos de 2020?

# %%
pd.DataFrame({'clean20': pd.Series(clean20.columns), 'clean10': pd.Series(clean10.columns)})
# Out:
#        clean20     clean10
# 0        index       index
# 1      NOM_MUN     NOM_MUN
# 2          LOC         LOC
# 3      NOM_LOC     NOM_LOC
# 4         AGEB        AGEB
# 5          MZA         MZA
# 6       POBTOT     P_TOTAL
# 7        P_0A2       P_0A2
# 8        P_3A5       P_3A5
# 9    POB65_MAS   POB65_MAS
# 10    GRAPROES    GRAPROES
# 11    PROM_HNV    PROM_HNV
# 12      PNACOE      VIVTOT
# 13      VIVTOT  PRO_OCUP_C
# 14   PROM_OCUP   PROM_OCUP
# 15  PRO_OCUP_C      VPH_PC
# 16      VPH_PC      PNACOE

# %% [markdown]
# renombramos POBTOT en 2020 por P_TOTAL, la de 2010

# %%
clean20 = clean20.rename(columns={'POBTOT': 'P_TOTAL'})
pd.DataFrame({'clean20': pd.Series(clean20.columns), 'clean10': pd.Series(clean10.columns)})
# Out:
#        clean20     clean10
# 0        index       index
# 1      NOM_MUN     NOM_MUN
# 2          LOC         LOC
# 3      NOM_LOC     NOM_LOC
# 4         AGEB        AGEB
# 5          MZA         MZA
# 6      P_TOTAL     P_TOTAL
# 7        P_0A2       P_0A2
# 8        P_3A5       P_3A5
# 9    POB65_MAS   POB65_MAS
# 10    GRAPROES    GRAPROES
# 11    PROM_HNV    PROM_HNV
# 12      PNACOE      VIVTOT
# 13      VIVTOT  PRO_OCUP_C
# 14   PROM_OCUP   PROM_OCUP
# 15  PRO_OCUP_C      VPH_PC
# 16      VPH_PC      PNACOE

# %% [markdown]
# ahora los nombres ya coinciden, solo falta ordenarlos igual

# %%
# get the column order of df1
column_order = clean10.columns

# reindex df2 using the column order of df1
clean20 = clean20.reindex(columns=column_order)

# %% [markdown]
# como se ve ahora?

# %%
pd.DataFrame({'clean20': pd.Series(clean20.columns), 'clean10': pd.Series(clean10.columns)})
# Out:
#        clean20     clean10
# 0        index       index
# 1      NOM_MUN     NOM_MUN
# 2          LOC         LOC
# 3      NOM_LOC     NOM_LOC
# 4         AGEB        AGEB
# 5          MZA         MZA
# 6      P_TOTAL     P_TOTAL
# 7        P_0A2       P_0A2
# 8        P_3A5       P_3A5
# 9    POB65_MAS   POB65_MAS
# 10    GRAPROES    GRAPROES
# 11    PROM_HNV    PROM_HNV
# 12      VIVTOT      VIVTOT
# 13  PRO_OCUP_C  PRO_OCUP_C
# 14   PROM_OCUP   PROM_OCUP
# 15      VPH_PC      VPH_PC
# 16      PNACOE      PNACOE

# %% [markdown]
# ### quitamos acentos

# %% [markdown]
# vamos a quitar todos los acentos de la columna NOM_LOC

# %%
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import unidecode

# remove accents
clean10['NOM_LOC'] = clean10['NOM_LOC'].apply(lambda x: unidecode.unidecode(x))

# remove accents
clean20['NOM_LOC'] = clean20['NOM_LOC'].apply(lambda x: unidecode.unidecode(x))

# %% [markdown]
# # EXPORTAR DATOS LIMPIOS

# %% [markdown]
# datos limpios:

# %%
clean10
# Out:
#       index   NOM_MUN   LOC                                 NOM_LOC  AGEB  \
# 0         4  Ensenada     1                                Ensenada  0435
# 1         5  Ensenada     1                                Ensenada  0435
# 2         6  Ensenada     1                                Ensenada  0435
# 3         7  Ensenada     1                                Ensenada  0435
# 4         8  Ensenada     1                                Ensenada  0435
# ...     ...       ...   ...                                     ...   ...
# 7026   8846  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 7027   8847  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 7028   8848  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 7029   8849  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 7030   8850  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
#
#       MZA  P_TOTAL P_0A2 P_3A5 POB65_MAS GRAPROES PROM_HNV  VIVTOT PRO_OCUP_C  \
# ...

# %%
clean20
# Out:
#       index   NOM_MUN   LOC                                 NOM_LOC  AGEB  \
# 0         4  Ensenada     1                                Ensenada  0026
# 1         5  Ensenada     1                                Ensenada  0026
# 2         6  Ensenada     1                                Ensenada  0026
# 3         8  Ensenada     1                                Ensenada  0030
# 4         9  Ensenada     1                                Ensenada  0030
# ...     ...       ...   ...                                     ...   ...
# 8005   8323  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 8006   8324  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 8007   8325  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 8008   8326  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
# 8009   8327  Ensenada  2183  Rancho Canon Buena Vista (El Zorrillo)  9782
#
#       MZA  P_TOTAL P_0A2 P_3A5 POB65_MAS GRAPROES PROM_HNV  VIVTOT PRO_OCUP_C  \
# ...

# %% [markdown]
# exportamos:

# %%
from google.colab import files

# create your dataframe

# export dataframe as csv and save as 'example.csv'
clean10.to_csv('clean10.csv', index=False)
clean20.to_csv('clean20.csv', index=False)

# download the csv file in Google Colab
files.download('clean10.csv')
files.download('clean20.csv')

# %% [markdown]
# seguiremos trabajando con los datos en otro notebook
